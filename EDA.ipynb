# %% [markdown]
# EDA

# %%
#imported all the requirements pandas for dataframe,matplotlib and seaborn for plotting
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\caash\Downloads\deliveries_updated_mens_ipl_upto_2024 - deliveries_updated_mens_ipl_upto_2024.csv")

# %%
df.head()
# Out:
#    matchId  inning  over_ball  over  ball           batting_team  \
# 0   335982       1        0.1     0     1  Kolkata Knight Riders
# 1   335982       1        0.2     0     2  Kolkata Knight Riders
# 2   335982       1        0.3     0     3  Kolkata Knight Riders
# 3   335982       1        0.4     0     4  Kolkata Knight Riders
# 4   335982       1        0.5     0     5  Kolkata Knight Riders
#
#                   bowling_team      batsman  non_striker   bowler  \
# 0  Royal Challengers Bangalore   SC Ganguly  BB McCullum  P Kumar
# 1  Royal Challengers Bangalore  BB McCullum   SC Ganguly  P Kumar
# 2  Royal Challengers Bangalore  BB McCullum   SC Ganguly  P Kumar
# 3  Royal Challengers Bangalore  BB McCullum   SC Ganguly  P Kumar
# 4  Royal Challengers Bangalore  BB McCullum   SC Ganguly  P Kumar
#
#    batsman_runs  extras  isWide  isNoBall  Byes  LegByes  Penalty  \
# 0             0       1     NaN       NaN   NaN      1.0      NaN
# ...

# %%
print(df.columns)
df.describe()
# Out:
# Index(['matchId', 'inning', 'over_ball', 'over', 'ball', 'batting_team',
#        'bowling_team', 'batsman', 'non_striker', 'bowler', 'batsman_runs',
#        'extras', 'isWide', 'isNoBall', 'Byes', 'LegByes', 'Penalty',
#        'dismissal_kind', 'player_dismissed', 'date'],
#       dtype='object')
#             matchId         inning      over_ball           over  \
# count  2.609200e+05  260920.000000  260920.000000  260920.000000
# mean   9.070665e+05       1.483531       9.560015       9.197677
# std    3.679913e+05       0.502643       5.686116       5.683484
# min    3.359820e+05       1.000000       0.100000       0.000000
# 25%    5.483340e+05       1.000000       4.500000       4.000000
# 50%    9.809670e+05       1.000000       9.400000       9.000000
# 75%    1.254066e+06       2.000000      14.400000      14.000000
# max    1.426312e+06       6.000000      19.900000      19.000000
#
#                 ball   batsman_runs         extras       isWide     isNoBall  \
# ...

# %%
#Below code is for histogram plot along with kde curve which tells distribution between count and batsman's runs
sns.histplot(data=df, x="batsman_runs", kde=True)
plt.show()

# %%
#Special type of scatter plot explaing batsman_runs according there teams
plt.figure(figsize=(16,8))
sns.lmplot(data=df, x="over_ball", y="batsman_runs", hue="batting_team",palette="colorblind")
plt.show()

# %%
#This is distribution of noballs according to team
sns.boxplot(data=df, x="bowling_team", y="isNoBall") #params required are data,column for x-axis ans other column for y-axis
plt.xticks(rotation=90) #for better visualization
plt.title("Distribution of Noballs by Team")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv(r"C:\Users\caash\Downloads\deliveries_updated_mens_ipl_upto_2024 - deliveries_updated_mens_ipl_upto_2024.csv")

# %%
top_teams = df["batting_team"].value_counts().nlargest(5).index#filtered top 5 teams
zoom_df = df[df["batting_team"].isin(top_teams)]
plt.figure(figsize=(16,8))#for better figure size
sns.violinplot(data=zoom_df,x="batting_team",y="batsman",hue="dismissal_kind")#differentiated according to dismissal kind
plt.legend(title='Batting Team', bbox_to_anchor=(1.05, 1), loc='upper left')#because violinplot was covered by legend
plt.xticks(rotation=90)
plt.yticks([])
plt.title("Batsman Dismissal Kind")
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.countplot(data=df, x="batsman_runs", hue="batting_team", palette="tab20")
plt.legend(title='Batting Team', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()#for making spacing easier
plt.title("Frequency of Run Types by Team")
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.scatterplot(data=df,x="bowling_team",y="extras")
plt.title("Extras Bowled By Each Team")
plt.xticks(rotation=90)
plt.xlabel("Teams")
plt.ylabel("Extras")
plt.show()

# %%
#all plots
df.hist(bins=40,figsize=(20,8))
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.scatterplot(data=df,x="over_ball",y="batsman_runs",hue="batting_team",alpha=0.5,palette="tab20")
plt.tight_layout()
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
df.plot(kind="scatter",x="bowling_team",y="LegByes",grid=True,alpha=1)
plt.xticks(rotation=90)
plt.show()

# %%
b=df[df["batsman"]=="V Kohli"]
sns.scatterplot(data=b,x="dismissal_kind",y="over_ball")
plt.show()

# %%
b=df[df["batsman"]=="V Kohli"]
sns.countplot(data=b,x="dismissal_kind")
plt.show()

# %%
r=df[df["bowler"]=="JJ Bumrah"]
sns.countplot(data=r,x="dismissal_kind")
plt.title("Most Types of wicket taken by JJ Bumrah")
plt.xlabel("Dismissal Types")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler,MinMaxScaler
import seaborn as sns
df=pd.read_csv(r"C:\Users\caash\Downloads\deliveries_updated_mens_ipl_upto_2024 - deliveries_updated_mens_ipl_upto_2024.csv")
plt.figure(figsize=(16,8))
sns.lineplot(data=df,x="over",y="dismissal_kind",hue="batting_team",palette="colorblind")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
teams=["Mumbai Indians","Chennai Super Kings","Rising Pune Supergiants"]
new_df=df[df["batting_team"].isin(teams)]
dismissal_counts = new_df.groupby(["batting_team", "dismissal_kind"]).size().reset_index(name="count")
sns.lineplot(data=dismissal_counts,x="batting_team",y="count",hue="dismissal_kind",palette="colorblind")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
extra_col=["isWide","isNoBall","Byes","LegByes","Penalty"]
extras_sum=df.groupby("bowling_team")[extra_col].sum()
sns.heatmap(extras_sum,annot=True,cmap="YlGnBu",fmt=".0f")
plt.show()

# %%
df=pd.read_csv(r"C:\Users\caash\Downloads\deliveries_updated_mens_ipl_upto_2024 - deliveries_updated_mens_ipl_upto_2024.csv")

# %%
# !pip install plotly
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: C:\Users\caash\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import plotly.express as px
batters=["V Kohli","RG Sharma","HH Pandya"]
b_df=df[(df["batsman"].isin(batters)) & (df["batsman_runs"].isin([4,6]))]
bo_cnt=b_df.groupby(["batsman","over_ball","batsman_runs"]).size().reset_index(name="count")
fig = px.bar(bo_cnt,x="over_ball",y="count",color="batsman",hover_data=["batsman"])
fig.update_layout(height=600)
fig.show()
